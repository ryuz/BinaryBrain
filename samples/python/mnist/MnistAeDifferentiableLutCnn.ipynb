# %% [markdown]
# # 微分可能LUTモデルによるMNISTでの Auto Encoder 学習
#
# Differentiable LUTモデルを用いて MNIST 画像の Auto Encoder を作成してみます。<br>
# ネットワークモデルにはCNNを用いています。
# バイナリであっても今のところある程度機能しており、一度 32ch まで圧縮した後に復元させています。

# %% [markdown]
# ## 事前準備

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import torch
import torchvision
import torchvision.transforms as transforms

import binarybrain as bb

# %% [markdown]
# 異なる閾値で2値化した画像でフレーム数を水増ししながら学習させます。この水増しをバイナリ変調と呼んでいます。<br>
# ここではフレーム方向の水増し量を frame_modulation_size で指定しています。<br>
# 別途 CIFAR-10などでも実験していますが、変調によりバイナリであってもある程度の階調表現の復元が行えるようです。

# %%
# configuration
net_name              = 'MnistAeDifferentiableLutCnn'
data_path             = os.path.join('./data/', net_name)

bin_mode              = False
epochs                = 4
mini_batch_size       = 32
frame_modulation_size = 7

# %% [markdown]
# データセットは PyTorch の torchvision を使います。<br>
# BinaryBrainではミニバッチをフレーム数として FrameBufferオブジェクトで扱います。<br>
# バイナリ変調で計算中にフレーム数が変わるためデータセットの準備観点でのミニバッチと呼び分けています。

# %%
# dataset
dataset_path = './data/'
dataset_train = torchvision.datasets.MNIST(root=dataset_path, train=True, transform=transforms.ToTensor(), download=True)
dataset_test  = torchvision.datasets.MNIST(root=dataset_path, train=False, transform=transforms.ToTensor(), download=True)
loader_train = torch.utils.data.DataLoader(dataset=dataset_train, batch_size=mini_batch_size, shuffle=True, num_workers=2)
loader_test  = torch.utils.data.DataLoader(dataset=dataset_test,  batch_size=mini_batch_size, shuffle=False, num_workers=2)

# %% [markdown]
# ## ネットワークの構築
#
# 畳み込みを行い 1x1x32ch (バイナリなので32bit)まで圧縮した後に復元するネットワークを作ります。
# なお、最後の方の層で batch_norm=False としています。
# 扱う画像自体が正規化されたものではないので、BatchNormalization を取り外しています。

# %%
# バイナリ時は BIT型を使えばメモリ削減可能
bin_dtype = bb.DType.BIT if bin_mode else bb.DType.FP32
#bin_dtype = bb.DType.FP32

# define network
net = bb.Sequential([
        bb.RealToBinary(frame_modulation_size=frame_modulation_size, bin_dtype=bin_dtype),
        
        # Encoder
        bb.Sequential([
            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([192], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([32],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([192], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([32],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.MaxPooling(filter_size=(2, 2), fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([384], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([64],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([384], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([64],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.MaxPooling(filter_size=(2, 2), fw_dtype=bin_dtype),

            bb.DifferentiableLut([1152], bin_dtype=bin_dtype),
            bb.DifferentiableLut([192],  bin_dtype=bin_dtype),
            bb.DifferentiableLut([32],   bin_dtype=bin_dtype),
        ]),
        
        # Decoder
        bb.Sequential([
            bb.DifferentiableLut([125],      bin_dtype=bin_dtype),
            bb.DifferentiableLut([1024],     bin_dtype=bin_dtype),
            bb.DifferentiableLut([64, 7, 7], bin_dtype=bin_dtype),
            
            bb.UpSampling(filter_size=(2, 2), fw_dtype=bin_dtype),
            
            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([384], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([64],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([384], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([64],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.UpSampling(filter_size=(2, 2), fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([192], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([32],  bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),

            bb.Convolution2d(
                bb.Sequential([
                    bb.DifferentiableLut([216], bin_dtype=bin_dtype),
                    bb.DifferentiableLut([36],  batch_norm=True, bin_dtype=bin_dtype),
                    bb.DifferentiableLut([6],   batch_norm=False, bin_dtype=bin_dtype),
                    bb.DifferentiableLut([1],   batch_norm=False, bin_dtype=bin_dtype),
                ]),
                filter_size=(3, 3), padding="same", fw_dtype=bin_dtype),
        ]),
    
        bb.BinaryToReal(frame_integration_size=frame_modulation_size, bin_dtype=bin_dtype),
    ])

net.set_input_shape([1, 28, 28])

if bin_mode:
    net.send_command("binary true")
else:
    net.send_command("binary false")

# print(net.get_info(3))

# %% [markdown]
# ## 学習の実施
#
# 入力画像そのものを期待値として、損失関数には平均二乗誤差(MSE)を使います。

# %%
loss      = bb.LossMeanSquaredError()
metrics   = bb.MetricsMeanSquaredError()
optimizer = bb.OptimizerAdam()

optimizer.set_variables(net.get_parameters(), net.get_gradients())

# %%
#bb.load_networks(data_path, net)

# learning
for epoch in range(epochs):
    # learning
    loss.clear()
    metrics.clear()
    with tqdm(loader_train) as t:
        for images, labels in t:
            x_buf = bb.FrameBuffer.from_numpy(np.array(images).astype(np.float32))
            y_buf = net.forward(x_buf, train=True)
            dy_buf = loss.calculate(y_buf, x_buf)
            net.backward(dy_buf)
            optimizer.update()
            t.set_postfix(loss=loss.get())

    # test
    loss.clear()
    metrics.clear()
    for images, labels in loader_test:
        x_buf = bb.FrameBuffer.from_numpy(np.array(images).astype(np.float32))
        y_buf = net.forward(x_buf, train=False)
        loss.calculate(y_buf, x_buf)
        metrics.calculate(y_buf, x_buf)

    print('epoch[%d] : loss(MSE)=%f' % (epoch, loss.get()))

    bb.save_networks(data_path, net)
# Out:
#   0%|          | 0/1875 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5195d3773364> in <module>
#      11             y_buf = net.forward(x_buf, train=True)
#      12             dy_buf = loss.calculate(y_buf, x_buf)
# ---> 13             net.backward(dy_buf)
#      14             optimizer.update()
#      15             t.set_postfix(loss=loss.get())
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\models.py in backward(self, dy_buf)
#     485     def backward(self, dy_buf):
#     486         for model in reversed(self.model_list):
# --> 487             dy_buf = model.backward(dy_buf)
#     488         return dy_buf
#     489
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\models.py in backward(self, dy_buf)
#     485     def backward(self, dy_buf):
#     486         for model in reversed(self.model_list):
# --> 487             dy_buf = model.backward(dy_buf)
#     488         return dy_buf
#     489
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\models.py in backward(self, dy_buf)
#     485     def backward(self, dy_buf):
#     486         for model in reversed(self.model_list):
# --> 487             dy_buf = model.backward(dy_buf)
#     488         return dy_buf
#     489
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\models.py in backward(self, dy_buf)
#     485     def backward(self, dy_buf):
#     486         for model in reversed(self.model_list):
# --> 487             dy_buf = model.backward(dy_buf)
#     488         return dy_buf
#     489
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\models.py in backward(self, dy_buf)
#     309         core_model = self.get_core()
#     310         if core_model is not None:
# --> 311             return bb.FrameBuffer.from_core(core_model.backward(dy_buf.get_core()))
#     312         return dy_buf
#     313
#
# d:\home\ryuji\git_work\github\binarybrain_ver4_develop\python\binarybrain\frame_buffer.py in from_core(core_buf)
#      38         super(FrameBuffer, self).__init__(core_object=core_buf)
#      39
# ---> 40     @staticmethod
#      41     def from_core(core_buf):
#      42         return FrameBuffer(core_buf=core_buf)
#
# KeyboardInterrupt:

# %%
print(net.get_info())
# Out:
# ----------------------------------------------------------------------
# [Sequential]
#  input  shape : [1, 28, 28] output shape : [1, 28, 28]
#   --------------------------------------------------------------------
#   [RealToBinary]
#    input  shape : {1, 28, 28} output shape : {1, 28, 28}
#   --------------------------------------------------------------------
#   [Sequential]
#    input  shape : [1, 28, 28]   output shape : [192]
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [1, 28, 28]     output shape : [32, 28, 28]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {1, 28, 28} output shape : {1, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [1, 3, 3]       output shape : [192]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {1, 3, 3} output shape : {192}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {192} output shape : {32}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {32} output shape : {32, 28, 28}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [32, 28, 28]     output shape : [32, 28, 28]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {32, 28, 28} output shape : {32, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [32, 3, 3]       output shape : [192]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {32, 3, 3} output shape : {192}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {192} output shape : {32}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {32} output shape : {32, 28, 28}
#     ------------------------------------------------------------------
#     [MaxPooling]
#      filter size : (2, 2)
#      input  shape : {32, 28, 28} output shape : {32, 14, 14}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [32, 14, 14]     output shape : [64, 14, 14]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {32, 14, 14} output shape : {32, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [32, 3, 3]       output shape : [384]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {32, 3, 3} output shape : {384}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {384} output shape : {64}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {64} output shape : {64, 14, 14}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [64, 14, 14]     output shape : [64, 14, 14]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {64, 14, 14} output shape : {64, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [64, 3, 3]       output shape : [384]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {64, 3, 3} output shape : {384}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {384} output shape : {64}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {64} output shape : {64, 14, 14}
#     ------------------------------------------------------------------
#     [MaxPooling]
#      filter size : (2, 2)
#      input  shape : {64, 14, 14} output shape : {64, 7, 7}
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {64, 7, 7} output shape : {1152}
#      binary : 0     batch_norm : 1
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {1152} output shape : {192}
#      binary : 0     batch_norm : 1
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {192} output shape : {32}
#      binary : 0     batch_norm : 1
#   --------------------------------------------------------------------
#   [Sequential]
#    input  shape : [32]   output shape : [32, 28, 28]
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {32} output shape : {125}
#      binary : 0     batch_norm : 1
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {125} output shape : {1024}
#      binary : 0     batch_norm : 1
#     ------------------------------------------------------------------
#     [DifferentiableLut6]
#      input  shape : {1024} output shape : {64, 7, 7}
#      binary : 0     batch_norm : 1
#     ------------------------------------------------------------------
#     [UpSampling]
#      input  shape : {64, 7, 7} output shape : {64, 14, 14}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [64, 14, 14]     output shape : [64, 14, 14]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {64, 14, 14} output shape : {64, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [64, 3, 3]       output shape : [384]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {64, 3, 3} output shape : {384}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {384} output shape : {64}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {64} output shape : {64, 14, 14}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [64, 14, 14]     output shape : [64, 14, 14]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {64, 14, 14} output shape : {64, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [64, 3, 3]       output shape : [384]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {64, 3, 3} output shape : {384}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {384} output shape : {64}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {64} output shape : {64, 14, 14}
#     ------------------------------------------------------------------
#     [UpSampling]
#      input  shape : {64, 14, 14} output shape : {64, 28, 28}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [64, 28, 28]     output shape : [32, 28, 28]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {64, 28, 28} output shape : {64, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [64, 3, 3]       output shape : [192]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {64, 3, 3} output shape : {192}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {192} output shape : {32}
#          binary : 0         batch_norm : 1
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {32} output shape : {32, 28, 28}
#     ------------------------------------------------------------------
#     [Convolution2d]
#      input  shape : [32, 28, 28]     output shape : [1, 28, 28]
#       ----------------------------------------------------------------
#       [ConvolutionIm2Col]
#        input  shape : {32, 28, 28} output shape : {32, 3, 3}
#       ----------------------------------------------------------------
#       [Sequential]
#        input  shape : [32, 3, 3]       output shape : [6]
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {32, 3, 3} output shape : {216}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {216} output shape : {36}
#          binary : 0         batch_norm : 1
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {36} output shape : {6}
#          binary : 0         batch_norm : 0
#         --------------------------------------------------------------
#         [DifferentiableLut6]
#          input  shape : {6} output shape : {1}
#          binary : 0         batch_norm : 0
#       ----------------------------------------------------------------
#       [ConvolutionCol2Im]
#        input  shape : {1} output shape : {1, 28, 28}
#   --------------------------------------------------------------------
#   [BinaryToReal]
#    input  shape : {1, 28, 28} output shape : {1, 28, 28}
# ----------------------------------------------------------------------

# %% [markdown]
# ## 結果を表示してみる
#
# 入力画像(x)と、一度圧縮して縮小した画像(y)の２つを10個表示してみます。

# %%
# 最新の保存データ読み込み
bb.load_networks(data_path, net)

# %%
for images, labels in loader_test:
    x_buf = bb.FrameBuffer.from_numpy(np.array(images).astype(np.float32))
    y_buf = net.forward(x_buf, train=True)
    break

# %%
x = x_buf.numpy()
y = y_buf.numpy()

# %%
plt.figure(figsize=(12,4))
for i in range(10):
    plt.subplot(2, 10, i+1)
    plt.title('x[%d]'%i)
    plt.imshow(x[i][0], 'gray')
    plt.subplot(2, 10, i+11)
    plt.title('y[%d]'%i)
    plt.imshow(y[i][0], 'gray')
plt.tight_layout()
